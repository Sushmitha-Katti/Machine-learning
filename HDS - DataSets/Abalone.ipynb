# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./abalone.csv")

# %%
df.columns = ['sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']

# %%
df
# Out:
#      sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.350     0.265   0.090        0.2255          0.0995
# 1      F   0.530     0.420   0.135        0.6770          0.2565
# 2      M   0.440     0.365   0.125        0.5160          0.2155
# 3      I   0.330     0.255   0.080        0.2050          0.0895
# 4      I   0.425     0.300   0.095        0.3515          0.1410
# 5      F   0.530     0.415   0.150        0.7775          0.2370
# 6      F   0.545     0.425   0.125        0.7680          0.2940
# 7      M   0.475     0.370   0.125        0.5095          0.2165
# 8      F   0.550     0.440   0.150        0.8945          0.3145
# 9      F   0.525     0.380   0.140        0.6065          0.1940
# 10     M   0.430     0.350   0.110        0.4060          0.1675
# 11     M   0.490     0.380   0.135        0.5415          0.2175
# 12     F   0.535     0.405   0.145        0.6845          0.2725
# ...

# %%
len(set(df['Rings']))
# Out:
# 28

# %%
plt.scatter(df['Diameter'],df['Rings'],c=df['Rings'])

# %%
correlation = df.corr('pearson')

# %%
abs(correlation['Rings']).sort_values()
# Out:
# Shucked weight    0.421256
# Viscera weight    0.504274
# Whole weight      0.540818
# Length            0.557123
# Height            0.558109
# Diameter          0.575005
# Shell weight      0.628031
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
#x = df.loc[:, : ]
x =df.drop(['Rings'], axis=1)


y = pd.DataFrame(df['Rings'],columns = ['Rings'])

# %%
plt.scatter(x['Shell weight'],y,c=np.array(y).ravel(), s=15)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.3)
ytest.size
#y = np.array(xtest[[f1,f2,f3,f4,f5,f6,f7]])
# Out:
# 1253

# %%
#basex = np.array(xtrain[[f1,f2,f3,f4,f5,f6,f7]])

ytest = pd.DataFrame(ytest, columns = ['Rings'])

# %%
f1 = 'Shell weight'
f2 = 'Diameter'
f3 = 'Height'
f4 = 'Length'
f5 = 'Whole weight'
f6 = 'Viscera weight'
f7 = 'Shucked weight'

basex = np.array(xtrain[[f1,f2,f3,f4,f5,f6,f7]])
xtest =  np.array(xtest[[f1,f2,f3,f4,f5,f6,f7]])
#basey =  np.array(xtrain[[f1,f2]])
basey = np.array(ytrain[['Rings']])
ytest = np.array(ytest[['Rings']])

# %%
#x = pd.DataFrame(basex)
#y = pd.DataFrame(basey)

#ax = plt.axes(projection='3d')
#ax.scatter(x.iloc[:,0], x.iloc[:,1] ,c=y.ravel(), s=15)
#ax.scatter(0.25, 0.2, c='r', marker='x', s=100)

# %%
k= np.sqrt(len(x))
k
# Out:
# 64.62197768561404

# %%
def euclid_distance(train_point, given_point):
   
    distance = np.sum((train_point-given_point)**2)
   
    return np.sqrt(distance)

# %%
def calc_distance_from_all(all_points, given_point, predictions):
    all_distances = []
    for i, each in enumerate(all_points):
        distance = euclid_distance(each, given_point)
        all_distances.append((distance,int(predictions[i])))
    all_distances.sort(key=lambda tup: tup[0])
    return all_distances

# %%
def get_neighbours(distances, count):
    return distances[:count]

# %%
def predict(all_points, given_point, predictions):
    distances = calc_distance_from_all(all_points,given_point,predictions)
    neighbours = get_neighbours(distances, 2)
    
    op = [row[-1] for row in neighbours]
    prediction = max(set(op), key=op.count)
    return prediction

# %%
def accuracy(basex, basey, testx, testy):
    correct = 0 
    
    for i in range(len(testx)):
        p = predict(basex, testx[i], basey)
        if p == testy[i]:
            correct += 1
            
    return f"Accuracy: {correct*100/len(testy)}%"

# %%
print(accuracy(basex,basey,xtest,ytest))
#print(basex.size,basey.size,xtest.size,ytest.size)
# Out:
# Accuracy: 21.46847565841979%
