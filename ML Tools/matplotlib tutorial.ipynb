# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
a = np.arange(10)
b = np.arange(10,20)

# %%
plt.plot(a,b ,'.')

# %%
plt.plot(a,b**2, 'y--')

# %%
c = a*2

# %%
plt.plot(a,b,"r.")
plt.plot(a,c,"y^")

# %%
a = np.arange(0,1,0.001)

# %%
plt.plot(a,np.sin(2*np.pi*a))

# %%
b = np.linspace(0,10,1000)

# %%
plt.plot(b, np.sin(2*np.pi*b))

# %%
b = np.linspace(-10, 10,1000)

# %%
plt.plot(b,b**2,"r")

# %%
plt.plot(b,b**3)

# %%
b = np.linspace(10,20,100)

# %%
fig = plt.figure()
plt.subplot(221)
p = plt.plot(b,np.cos(2*np.pi*b))

plt.subplot(222)
plt.plot(b, np.exp(-b),)

plt.subplot(212)
plt.plot(b, (np.cos(2*np.pi*b)*np.exp(-b)))

# %%
plt.plot(b,np.cos(2*np.pi*b))
plt.plot(b,(np.cos(2*np.pi*b)*np.exp(-b)),)
plt.plot(b, np.exp(-b),)

# %%
t =np.arange(0,10,0.1)

# %%
x = np.sin(t)
y = np.cos(t)

# %%
plt.plot(t,x, 'r.',
         t,y ,'b.',
        t,x+y,'g.',
        t,x*y)

# %%
y
